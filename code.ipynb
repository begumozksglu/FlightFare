# %% [markdown]
# ### FEATURES:
#
# #### Airline: The name of the airline.
#
# #### Date_of_Journey: The date of the journey
#
# #### Source: The source from which the service begins.
#
# #### Destination: The destination where the service ends.
#
# #### Route: The route taken by the flight to reach the destination.
#
# #### Dep_Time: The time when the journey starts from the source.
#
# #### Arrival_Time: Time of arrival at the destination.
#
# #### Duration: Total duration of the flight.
#
# #### Total_Stops: Total stops between the source and destination.
#
# #### Additional_Info: Additional information about the flight
#
# #### Price: The price of the ticket

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df= pd.read_csv("flight data.csv")
df1= pd.read_csv("flight test.csv")

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.shape
# Out:
# (10683, 11)

# %%
df1
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# 2     DEL → BOM → COK    19:15  19:00 22 May  23h 45m      1 stop
# 3     DEL → BOM → COK    08:00         21:00      13h      1 stop
# 4           BLR → DEL    23:55  02:45 25 Jun   2h 50m    non-stop
# ...               ...      ...           ...      ...         ...
# 2666  CCU → DEL → BLR    20:30  20:25 07 Jun  23h 55m      1 stop
# 2667        CCU → BLR    14:20         16:55   2h 35m    non-stop
# 2668  DEL → BOM → COK    21:50  04:25 07 Mar   6h 35m      1 stop
# 2669  DEL → BOM → COK    04:00         19:15  15h 15m      1 stop
# 2670  DEL → BOM → COK    04:55         19:15  14h 20m      1 stop
#
#                   Additional_Info
# 0                         No info
# 1                         No info
# 2     In-flight meal not included
# 3                         No info
# 4                         No info
# ...                           ...
# 2666                      No info
# 2667                      No info
# 2668                      No info
# 2669                      No info
# 2670                      No info
#
# [2671 rows x 10 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2671 entries, 0 to 2670
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2671 non-null   object
#  1   Date_of_Journey  2671 non-null   object
#  2   Source           2671 non-null   object
#  3   Destination      2671 non-null   object
#  4   Route            2671 non-null   object
#  5   Dep_Time         2671 non-null   object
#  6   Arrival_Time     2671 non-null   object
#  7   Duration         2671 non-null   object
#  8   Total_Stops      2671 non-null   object
#  9   Additional_Info  2671 non-null   object
# dtypes: object(10)
# memory usage: 208.8+ KB

# %%
df1.shape
# Out:
# (2671, 10)

# %%
total_df= df.append(df1,sort= False)
# Out:
# C:\Users\bozkisaoglu\AppData\Local\Temp\ipykernel_36512\2925819047.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_df= df.append(df1,sort= False)

# %%
total_df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2     DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3           CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4           BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                     ...      ...           ...      ...         ...
# 2666        CCU → DEL → BLR    20:30  20:25 07 Jun  23h 55m      1 stop
# 2667              CCU → BLR    14:20         16:55   2h 35m    non-stop
# 2668        DEL → BOM → COK    21:50  04:25 07 Mar   6h 35m      1 stop
# 2669        DEL → BOM → COK    04:00         19:15  15h 15m      1 stop
# 2670        DEL → BOM → COK    04:55         19:15  14h 20m      1 stop
#
#      Additional_Info    Price
# 0            No info   3897.0
# 1            No info   7662.0
# 2            No info  13882.0
# 3            No info   6218.0
# 4            No info  13302.0
# ...              ...      ...
# 2666         No info      NaN
# 2667         No info      NaN
# 2668         No info      NaN
# 2669         No info      NaN
# 2670         No info      NaN
#
# [13354 rows x 11 columns]

# %%
total_df.shape
# Out:
# (13354, 11)

# %%
df['Airline'].value_counts()
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %%
sns.catplot(y='Price',x='Airline',data= df.sort_values('Price',ascending=False),kind="boxen",height=6, aspect=3)
plt.show;

# %%
df['Source'].value_counts() ## checking for Source
# Out:
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %%
sns.catplot(y='Price',x='Source',data= df.sort_values('Price',ascending=False),kind="boxen",height=6, aspect=3)
plt.show;

# %%
df['Destination'].value_counts() ## checking for Destination
# Out:
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %%
sns.catplot(y='Price',x='Destination',data= df.sort_values('Price',ascending=False),kind="boxen",height=6, aspect=3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Duration'].value_counts()
# Out:
# 2h 50m     550
# 1h 30m     386
# 2h 45m     337
# 2h 55m     337
# 2h 35m     329
#           ...
# 31h 30m      1
# 30h 25m      1
# 42h 5m       1
# 4h 10m       1
# 47h 40m      1
# Name: Duration, Length: 368, dtype: int64

# %%
total_df['Date']=total_df['Date_of_Journey'].str.split('/').str[0]
total_df['Month']=total_df['Date_of_Journey'].str.split('/').str[1]
total_df['Year']=total_df['Date_of_Journey'].str.split('/').str[2]

# %%
total_df=total_df.drop(['Date_of_Journey'],axis=1)

# %%
total_df
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
#       Arrival_Time Duration Total_Stops Additional_Info    Price Date Month  \
# 0     01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24    03
# 1            13:15   7h 25m     2 stops         No info   7662.0    1    05
# 2     04:25 10 Jun      19h     2 stops         No info  13882.0    9    06
# 3            23:30   5h 25m      1 stop         No info   6218.0   12    05
# 4            21:35   4h 45m      1 stop         No info  13302.0   01    03
# ...            ...      ...         ...             ...      ...  ...   ...
# 2666  20:25 07 Jun  23h 55m      1 stop         No info      NaN    6    06
# 2667         16:55   2h 35m    non-stop         No info      NaN   27    03
# 2668  04:25 07 Mar   6h 35m      1 stop         No info      NaN    6    03
# 2669         19:15  15h 15m      1 stop         No info      NaN    6    03
# 2670         19:15  14h 20m      1 stop         No info      NaN   15    06
#
#       Year
# 0     2019
# 1     2019
# 2     2019
# 3     2019
# 4     2019
# ...    ...
# 2666  2019
# 2667  2019
# 2668  2019
# 2669  2019
# 2670  2019
#
# [13354 rows x 13 columns]

# %%
total_df['Date']=total_df['Date'].astype(int)
total_df['Month']=total_df['Month'].astype(int)
total_df['Year']=total_df['Year'].astype(int)

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  object
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
#  10  Date             13354 non-null  int32
#  11  Month            13354 non-null  int32
#  12  Year             13354 non-null  int32
# dtypes: float64(1), int32(3), object(9)
# memory usage: 1.3+ MB

# %%
total_df['Additional_Info'].value_counts()
# Out:
# No info                         10493
# In-flight meal not included      2426
# No check-in baggage included      396
# 1 Long layover                     20
# Change airports                     8
# Business class                      5
# No Info                             3
# 1 Short layover                     1
# Red-eye flight                      1
# 2 Long layover                      1
# Name: Additional_Info, dtype: int64

# %%
sns.catplot(y='Price',x='Additional_Info',data= df.sort_values('Price',ascending=False),kind="boxen",height=6, aspect=3)
plt.show;

# %%
total_df['Arrival_Time']=total_df['Arrival_Time'].str.split(' ').str[0]

# %%
total_df
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
#      Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0           01:10   2h 50m    non-stop         No info   3897.0    24      3
# 1           13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2           04:25      19h     2 stops         No info  13882.0     9      6
# 3           23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4           21:35   4h 45m      1 stop         No info  13302.0     1      3
# ...           ...      ...         ...             ...      ...   ...    ...
# 2666        20:25  23h 55m      1 stop         No info      NaN     6      6
# 2667        16:55   2h 35m    non-stop         No info      NaN    27      3
# 2668        04:25   6h 35m      1 stop         No info      NaN     6      3
# 2669        19:15  15h 15m      1 stop         No info      NaN     6      3
# 2670        19:15  14h 20m      1 stop         No info      NaN    15      6
#
#       Year
# 0     2019
# 1     2019
# 2     2019
# 3     2019
# 4     2019
# ...    ...
# 2666  2019
# 2667  2019
# 2668  2019
# 2669  2019
# 2670  2019
#
# [13354 rows x 13 columns]

# %%
total_df['Total_Stops'].value_counts()
# Out:
# 1 stop      7056
# non-stop    4340
# 2 stops     1899
# 3 stops       56
# 4 stops        2
# Name: Total_Stops, dtype: int64

# %%
total_df['Total_Stops']=total_df['Total_Stops'].fillna('1 stop')

# %%
total_df['Total_Stops'].isnull().sum()
# Out:
# 0

# %%
total_df
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
#      Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0           01:10   2h 50m    non-stop         No info   3897.0    24      3
# 1           13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2           04:25      19h     2 stops         No info  13882.0     9      6
# 3           23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4           21:35   4h 45m      1 stop         No info  13302.0     1      3
# ...           ...      ...         ...             ...      ...   ...    ...
# 2666        20:25  23h 55m      1 stop         No info      NaN     6      6
# 2667        16:55   2h 35m    non-stop         No info      NaN    27      3
# 2668        04:25   6h 35m      1 stop         No info      NaN     6      3
# 2669        19:15  15h 15m      1 stop         No info      NaN     6      3
# 2670        19:15  14h 20m      1 stop         No info      NaN    15      6
#
#       Year
# 0     2019
# 1     2019
# 2     2019
# 3     2019
# 4     2019
# ...    ...
# 2666  2019
# 2667  2019
# 2668  2019
# 2669  2019
# 2670  2019
#
# [13354 rows x 13 columns]

# %%
total_df['Total_Stops']=total_df['Total_Stops'].replace('non-stop','0 stop')

# %%
total_df
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
#      Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0           01:10   2h 50m      0 stop         No info   3897.0    24      3
# 1           13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2           04:25      19h     2 stops         No info  13882.0     9      6
# 3           23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4           21:35   4h 45m      1 stop         No info  13302.0     1      3
# ...           ...      ...         ...             ...      ...   ...    ...
# 2666        20:25  23h 55m      1 stop         No info      NaN     6      6
# 2667        16:55   2h 35m      0 stop         No info      NaN    27      3
# 2668        04:25   6h 35m      1 stop         No info      NaN     6      3
# 2669        19:15  15h 15m      1 stop         No info      NaN     6      3
# 2670        19:15  14h 20m      1 stop         No info      NaN    15      6
#
#       Year
# 0     2019
# 1     2019
# 2     2019
# 3     2019
# 4     2019
# ...    ...
# 2666  2019
# 2667  2019
# 2668  2019
# 2669  2019
# 2670  2019
#
# [13354 rows x 13 columns]

# %%
total_df['Stop'] = total_df['Total_Stops'].str.split(' ').str[0]

# %%
total_df
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
#      Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0           01:10   2h 50m      0 stop         No info   3897.0    24      3
# 1           13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2           04:25      19h     2 stops         No info  13882.0     9      6
# 3           23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4           21:35   4h 45m      1 stop         No info  13302.0     1      3
# ...           ...      ...         ...             ...      ...   ...    ...
# 2666        20:25  23h 55m      1 stop         No info      NaN     6      6
# 2667        16:55   2h 35m      0 stop         No info      NaN    27      3
# 2668        04:25   6h 35m      1 stop         No info      NaN     6      3
# 2669        19:15  15h 15m      1 stop         No info      NaN     6      3
# 2670        19:15  14h 20m      1 stop         No info      NaN    15      6
#
#       Year Stop
# 0     2019    0
# 1     2019    2
# 2     2019    2
# 3     2019    1
# 4     2019    1
# ...    ...  ...
# 2666  2019    1
# 2667  2019    0
# 2668  2019    1
# 2669  2019    1
# 2670  2019    1
#
# [13354 rows x 14 columns]

# %%
total_df=total_df.drop(['Total_Stops'],axis=1)

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Additional_Info  13354 non-null  object
#  8   Price            10683 non-null  float64
#  9   Date             13354 non-null  int32
#  10  Month            13354 non-null  int32
#  11  Year             13354 non-null  int32
#  12  Stop             13354 non-null  object
# dtypes: float64(1), int32(3), object(9)
# memory usage: 1.3+ MB

# %%
total_df['Stop']=total_df['Stop'].astype(int)

# %%
total_df['Arrival_Hour'] = total_df['Arrival_Time'] .str.split(':').str[0]
total_df['Arrival_Minute'] = total_df['Arrival_Time'] .str.split(':').str[1]

# %%
total_df['Arrival_Hour']=total_df['Arrival_Hour'].astype(int)
total_df['Arrival_Minute']=total_df['Arrival_Minute'].astype(int)
total_df=total_df.drop(['Arrival_Time'],axis=1)

# %%
total_df
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
#      Duration Additional_Info    Price  Date  Month  Year  Stop  Arrival_Hour  \
# 0      2h 50m         No info   3897.0    24      3  2019     0             1
# 1      7h 25m         No info   7662.0     1      5  2019     2            13
# 2         19h         No info  13882.0     9      6  2019     2             4
# 3      5h 25m         No info   6218.0    12      5  2019     1            23
# 4      4h 45m         No info  13302.0     1      3  2019     1            21
# ...       ...             ...      ...   ...    ...   ...   ...           ...
# 2666  23h 55m         No info      NaN     6      6  2019     1            20
# 2667   2h 35m         No info      NaN    27      3  2019     0            16
# 2668   6h 35m         No info      NaN     6      3  2019     1             4
# 2669  15h 15m         No info      NaN     6      3  2019     1            19
# 2670  14h 20m         No info      NaN    15      6  2019     1            19
#
#       Arrival_Minute
# 0                 10
# 1                 15
# 2                 25
# 3                 30
# 4                 35
# ...              ...
# 2666              25
# 2667              55
# 2668              25
# 2669              15
# 2670              15
#
# [13354 rows x 14 columns]

# %%
total_df['Departure_Hour'] = total_df['Dep_Time'] .str.split(':').str[0]
total_df['Departure_Minute'] = total_df['Dep_Time'] .str.split(':').str[1]

# %%
total_df['Departure_Hour']=total_df['Departure_Hour'].astype(int)
total_df['Departure_Minute']=total_df['Departure_Minute'].astype(int)
total_df=total_df.drop(['Dep_Time'],axis=1)

# %%
total_df
# Out:
#                 Airline    Source Destination                  Route Duration  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR  23h 55m
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR   2h 35m
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK   6h 35m
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK  15h 15m
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK  14h 20m
#
#      Additional_Info    Price  Date  Month  Year  Stop  Arrival_Hour  \
# 0            No info   3897.0    24      3  2019     0             1
# 1            No info   7662.0     1      5  2019     2            13
# 2            No info  13882.0     9      6  2019     2             4
# 3            No info   6218.0    12      5  2019     1            23
# 4            No info  13302.0     1      3  2019     1            21
# ...              ...      ...   ...    ...   ...   ...           ...
# 2666         No info      NaN     6      6  2019     1            20
# 2667         No info      NaN    27      3  2019     0            16
# 2668         No info      NaN     6      3  2019     1             4
# 2669         No info      NaN     6      3  2019     1            19
# 2670         No info      NaN    15      6  2019     1            19
#
#       Arrival_Minute  Departure_Hour  Departure_Minute
# 0                 10              22                20
# 1                 15               5                50
# 2                 25               9                25
# 3                 30              18                 5
# 4                 35              16                50
# ...              ...             ...               ...
# 2666              25              20                30
# 2667              55              14                20
# 2668              25              21                50
# 2669              15               4                 0
# 2670              15               4                55
#
# [13354 rows x 15 columns]

# %%
total_df['Route_1']= total_df['Route'].str.split('→ ').str[0]
total_df['Route_2']= total_df['Route'].str.split('→ ').str[1]
total_df['Route_3']= total_df['Route'].str.split('→ ').str[2]
total_df['Route_4']= total_df['Route'].str.split('→ ').str[3]
total_df['Route_5']= total_df['Route'].str.split('→ ').str[4]

# %%
total_df
# Out:
#                 Airline    Source Destination                  Route Duration  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR  23h 55m
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR   2h 35m
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK   6h 35m
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK  15h 15m
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK  14h 20m
#
#      Additional_Info    Price  Date  Month  Year  Stop  Arrival_Hour  \
# 0            No info   3897.0    24      3  2019     0             1
# 1            No info   7662.0     1      5  2019     2            13
# 2            No info  13882.0     9      6  2019     2             4
# 3            No info   6218.0    12      5  2019     1            23
# 4            No info  13302.0     1      3  2019     1            21
# ...              ...      ...   ...    ...   ...   ...           ...
# 2666         No info      NaN     6      6  2019     1            20
# 2667         No info      NaN    27      3  2019     0            16
# 2668         No info      NaN     6      3  2019     1             4
# 2669         No info      NaN     6      3  2019     1            19
# 2670         No info      NaN    15      6  2019     1            19
#
#       Arrival_Minute  Departure_Hour  Departure_Minute Route_1 Route_2  \
# 0                 10              22                20    BLR      DEL
# 1                 15               5                50    CCU     IXR
# 2                 25               9                25    DEL     LKO
# 3                 30              18                 5    CCU     NAG
# 4                 35              16                50    BLR     NAG
# ...              ...             ...               ...     ...     ...
# 2666              25              20                30    CCU     DEL
# 2667              55              14                20    CCU      BLR
# 2668              25              21                50    DEL     BOM
# 2669              15               4                 0    DEL     BOM
# 2670              15               4                55    DEL     BOM
#
#      Route_3 Route_4 Route_5
# 0        NaN     NaN     NaN
# 1       BBI      BLR     NaN
# 2       BOM      COK     NaN
# 3        BLR     NaN     NaN
# 4        DEL     NaN     NaN
# ...      ...     ...     ...
# 2666     BLR     NaN     NaN
# 2667     NaN     NaN     NaN
# 2668     COK     NaN     NaN
# 2669     COK     NaN     NaN
# 2670     COK     NaN     NaN
#
# [13354 rows x 20 columns]

# %%
total_df['Route_1'].fillna("None",inplace=True)
total_df['Route_2'].fillna("None",inplace=True)
total_df['Route_3'].fillna("None",inplace=True)
total_df['Route_4'].fillna("None",inplace=True)
total_df['Route_5'].fillna("None",inplace=True)

# %%
total_df
# Out:
#                 Airline    Source Destination                  Route Duration  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR  23h 55m
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR   2h 35m
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK   6h 35m
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK  15h 15m
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK  14h 20m
#
#      Additional_Info    Price  Date  Month  Year  Stop  Arrival_Hour  \
# 0            No info   3897.0    24      3  2019     0             1
# 1            No info   7662.0     1      5  2019     2            13
# 2            No info  13882.0     9      6  2019     2             4
# 3            No info   6218.0    12      5  2019     1            23
# 4            No info  13302.0     1      3  2019     1            21
# ...              ...      ...   ...    ...   ...   ...           ...
# 2666         No info      NaN     6      6  2019     1            20
# 2667         No info      NaN    27      3  2019     0            16
# 2668         No info      NaN     6      3  2019     1             4
# 2669         No info      NaN     6      3  2019     1            19
# 2670         No info      NaN    15      6  2019     1            19
#
#       Arrival_Minute  Departure_Hour  Departure_Minute Route_1 Route_2  \
# 0                 10              22                20    BLR      DEL
# 1                 15               5                50    CCU     IXR
# 2                 25               9                25    DEL     LKO
# 3                 30              18                 5    CCU     NAG
# 4                 35              16                50    BLR     NAG
# ...              ...             ...               ...     ...     ...
# 2666              25              20                30    CCU     DEL
# 2667              55              14                20    CCU      BLR
# 2668              25              21                50    DEL     BOM
# 2669              15               4                 0    DEL     BOM
# 2670              15               4                55    DEL     BOM
#
#      Route_3 Route_4 Route_5
# 0       None    None    None
# 1       BBI      BLR    None
# 2       BOM      COK    None
# 3        BLR    None    None
# 4        DEL    None    None
# ...      ...     ...     ...
# 2666     BLR    None    None
# 2667    None    None    None
# 2668     COK    None    None
# 2669     COK    None    None
# 2670     COK    None    None
#
# [13354 rows x 20 columns]

# %%
total_df=total_df.drop(['Route'],axis=1)
total_df=total_df.drop(['Duration'],axis=1)

# %%
total_df.head()
# Out:
#        Airline    Source Destination Additional_Info    Price  Date  Month  \
# 0       IndiGo  Banglore   New Delhi         No info   3897.0    24      3
# 1    Air India   Kolkata    Banglore         No info   7662.0     1      5
# 2  Jet Airways     Delhi      Cochin         No info  13882.0     9      6
# 3       IndiGo   Kolkata    Banglore         No info   6218.0    12      5
# 4       IndiGo  Banglore   New Delhi         No info  13302.0     1      3
#
#    Year  Stop  Arrival_Hour  Arrival_Minute  Departure_Hour  Departure_Minute  \
# 0  2019     0             1              10              22                20
# 1  2019     2            13              15               5                50
# 2  2019     2             4              25               9                25
# 3  2019     1            23              30              18                 5
# 4  2019     1            21              35              16                50
#
#   Route_1 Route_2 Route_3 Route_4 Route_5
# 0    BLR      DEL    None    None    None
# 1    CCU     IXR     BBI      BLR    None
# 2    DEL     LKO     BOM      COK    None
# 3    CCU     NAG      BLR    None    None
# 4    BLR     NAG      DEL    None    None

# %%
total_df.isnull().sum()
# Out:
# Airline                0
# Source                 0
# Destination            0
# Additional_Info        0
# Price               2671
# Date                   0
# Month                  0
# Year                   0
# Stop                   0
# Arrival_Hour           0
# Arrival_Minute         0
# Departure_Hour         0
# Departure_Minute       0
# Route_1                0
# Route_2                0
# Route_3                0
# Route_4                0
# Route_5                0
# dtype: int64

# %%
total_df['Price'].fillna((total_df['Price'].mean()),inplace=True)

# %%
total_df.isnull().sum()
# Out:
# Airline             0
# Source              0
# Destination         0
# Additional_Info     0
# Price               0
# Date                0
# Month               0
# Year                0
# Stop                0
# Arrival_Hour        0
# Arrival_Minute      0
# Departure_Hour      0
# Departure_Minute    0
# Route_1             0
# Route_2             0
# Route_3             0
# Route_4             0
# Route_5             0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le= LabelEncoder()

# %%
total_df["Airline"]=le.fit_transform(total_df['Airline'])
total_df["Source"]=le.fit_transform(total_df['Source'])
total_df["Destination"]=le.fit_transform(total_df['Destination'])
total_df["Additional_Info"]=le.fit_transform(total_df['Additional_Info'])
total_df["Route_1"]=le.fit_transform(total_df['Route_1'])
total_df["Route_2"]=le.fit_transform(total_df['Route_2'])
total_df["Route_3"]=le.fit_transform(total_df['Route_3'])
total_df["Route_4"]=le.fit_transform(total_df['Route_4'])
total_df["Route_5"]=le.fit_transform(total_df['Route_5'])

# %%
total_df
# Out:
#       Airline  Source  Destination  Additional_Info         Price  Date  \
# 0           3       0            5                8   3897.000000    24
# 1           1       3            0                8   7662.000000     1
# 2           4       2            1                8  13882.000000     9
# 3           3       3            0                8   6218.000000    12
# 4           3       0            5                8  13302.000000     1
# ...       ...     ...          ...              ...           ...   ...
# 2666        1       3            0                8   9087.064121     6
# 2667        3       3            0                8   9087.064121    27
# 2668        4       2            1                8   9087.064121     6
# 2669        1       2            1                8   9087.064121     6
# 2670        6       2            1                8   9087.064121    15
#
#       Month  Year  Stop  Arrival_Hour  Arrival_Minute  Departure_Hour  \
# 0         3  2019     0             1              10              22
# 1         5  2019     2            13              15               5
# 2         6  2019     2             4              25               9
# 3         5  2019     1            23              30              18
# 4         3  2019     1            21              35              16
# ...     ...   ...   ...           ...             ...             ...
# 2666      6  2019     1            20              25              20
# 2667      3  2019     0            16              55              14
# 2668      3  2019     1             4              25              21
# 2669      3  2019     1            19              15               4
# 2670      6  2019     1            19              15               4
#
#       Departure_Minute  Route_1  Route_2  Route_3  Route_4  Route_5
# 0                   20        0       13       24       12        4
# 1                   50        2       25        1        3        4
# 2                   25        3       32        4        5        4
# 3                    5        2       34        3       12        4
# 4                   50        0       34        8       12        4
# ...                ...      ...      ...      ...      ...      ...
# 2666                30        2       14        3       12        4
# 2667                20        2        5       24       12        4
# 2668                50        3        7        6       12        4
# 2669                 0        3        7        6       12        4
# 2670                55        3        7        6       12        4
#
# [13354 rows x 18 columns]

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Airline           13354 non-null  int32
#  1   Source            13354 non-null  int32
#  2   Destination       13354 non-null  int32
#  3   Additional_Info   13354 non-null  int32
#  4   Price             13354 non-null  float64
#  5   Date              13354 non-null  int32
#  6   Month             13354 non-null  int32
#  7   Year              13354 non-null  int32
#  8   Stop              13354 non-null  int32
#  9   Arrival_Hour      13354 non-null  int32
#  10  Arrival_Minute    13354 non-null  int32
#  11  Departure_Hour    13354 non-null  int32
#  12  Departure_Minute  13354 non-null  int32
#  13  Route_1           13354 non-null  int32
#  14  Route_2           13354 non-null  int32
#  15  Route_3           13354 non-null  int32
#  16  Route_4           13354 non-null  int32
#  17  Route_5           13354 non-null  int32
# dtypes: float64(1), int32(17)
# memory usage: 1.1 MB

# %%
total_df= total_df.drop(['Year'], axis=1) #because we have the dataset of the same year

# %%
total_df
# Out:
#       Airline  Source  Destination  Additional_Info         Price  Date  \
# 0           3       0            5                8   3897.000000    24
# 1           1       3            0                8   7662.000000     1
# 2           4       2            1                8  13882.000000     9
# 3           3       3            0                8   6218.000000    12
# 4           3       0            5                8  13302.000000     1
# ...       ...     ...          ...              ...           ...   ...
# 2666        1       3            0                8   9087.064121     6
# 2667        3       3            0                8   9087.064121    27
# 2668        4       2            1                8   9087.064121     6
# 2669        1       2            1                8   9087.064121     6
# 2670        6       2            1                8   9087.064121    15
#
#       Month  Stop  Arrival_Hour  Arrival_Minute  Departure_Hour  \
# 0         3     0             1              10              22
# 1         5     2            13              15               5
# 2         6     2             4              25               9
# 3         5     1            23              30              18
# 4         3     1            21              35              16
# ...     ...   ...           ...             ...             ...
# 2666      6     1            20              25              20
# 2667      3     0            16              55              14
# 2668      3     1             4              25              21
# 2669      3     1            19              15               4
# 2670      6     1            19              15               4
#
#       Departure_Minute  Route_1  Route_2  Route_3  Route_4  Route_5
# 0                   20        0       13       24       12        4
# 1                   50        2       25        1        3        4
# 2                   25        3       32        4        5        4
# 3                    5        2       34        3       12        4
# 4                   50        0       34        8       12        4
# ...                ...      ...      ...      ...      ...      ...
# 2666                30        2       14        3       12        4
# 2667                20        2        5       24       12        4
# 2668                50        3        7        6       12        4
# 2669                 0        3        7        6       12        4
# 2670                55        3        7        6       12        4
#
# [13354 rows x 17 columns]

# %%
x= total_df.drop(['Price'],axis=1)
y= total_df['Price']

# %%
x
# Out:
#       Airline  Source  Destination  Additional_Info  Date  Month  Stop  \
# 0           3       0            5                8    24      3     0
# 1           1       3            0                8     1      5     2
# 2           4       2            1                8     9      6     2
# 3           3       3            0                8    12      5     1
# 4           3       0            5                8     1      3     1
# ...       ...     ...          ...              ...   ...    ...   ...
# 2666        1       3            0                8     6      6     1
# 2667        3       3            0                8    27      3     0
# 2668        4       2            1                8     6      3     1
# 2669        1       2            1                8     6      3     1
# 2670        6       2            1                8    15      6     1
#
#       Arrival_Hour  Arrival_Minute  Departure_Hour  Departure_Minute  Route_1  \
# 0                1              10              22                20        0
# 1               13              15               5                50        2
# 2                4              25               9                25        3
# 3               23              30              18                 5        2
# 4               21              35              16                50        0
# ...            ...             ...             ...               ...      ...
# 2666            20              25              20                30        2
# 2667            16              55              14                20        2
# 2668             4              25              21                50        3
# 2669            19              15               4                 0        3
# 2670            19              15               4                55        3
#
#       Route_2  Route_3  Route_4  Route_5
# 0          13       24       12        4
# 1          25        1        3        4
# 2          32        4        5        4
# 3          34        3       12        4
# 4          34        8       12        4
# ...       ...      ...      ...      ...
# 2666       14        3       12        4
# 2667        5       24       12        4
# 2668        7        6       12        4
# 2669        7        6       12        4
# 2670        7        6       12        4
#
# [13354 rows x 16 columns]

# %%
y
# Out:
# 0        3897.000000
# 1        7662.000000
# 2       13882.000000
# 3        6218.000000
# 4       13302.000000
#             ...
# 2666     9087.064121
# 2667     9087.064121
# 2668     9087.064121
# 2669     9087.064121
# 2670     9087.064121
# Name: Price, Length: 13354, dtype: float64

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
model=SelectFromModel(Lasso(alpha=0.005,random_state=0))

# %%
model.fit(x_train,y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, random_state=0))

# %%
model.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
selected_features=x_train.columns[(model.get_support())]

# %%
selected_features
# Out:
# Index(['Airline', 'Source', 'Destination', 'Additional_Info', 'Date', 'Month',
#        'Stop', 'Arrival_Hour', 'Arrival_Minute', 'Departure_Hour',
#        'Departure_Minute', 'Route_1', 'Route_2', 'Route_3', 'Route_4',
#        'Route_5'],
#       dtype='object')

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
etr = ExtraTreesRegressor()
etr.fit(x_train,y_train)
# Out:
# ExtraTreesRegressor()

# %%
plt.style.use("ggplot")
plt.figure(figsize = (15,8))
feature_importances = pd.Series(etr.feature_importances_, index=x.columns)
feature_importances.nlargest(35).plot(kind='bar')
plt.show()

# %% [markdown]
# ### Importing our model

# %%
from sklearn.ensemble import RandomForestRegressor
reg_rf = RandomForestRegressor()
reg_rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = reg_rf.predict(x_test)

# %%
reg_rf.score(x_train, y_train)
# Out:
# 0.948395349026076

# %%
reg_rf.score(x_test, y_test)
# Out:
# 0.6199994894684232

# %%
plt.style.use("ggplot")
plt.figure(figsize=(12,8))
sns.distplot(y_test-y_pred)
plt.show()
# Out:
# C:\Users\bozkisaoglu\AppData\Local\Temp\ipykernel_36512\1894552590.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-y_pred)

# %%
plt.figure(figsize=(12,8))
plt.style.use("ggplot")
plt.scatter(y_test, y_pred, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 1533.3909790679406
# MSE: 6317811.039075677
# RMSE: 2513.5256193394325

# %%
metrics.r2_score(y_test, y_pred)
# Out:
# 0.6199994894684232

# %% [markdown]
# ### Hypertuning our Model

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1500, num = 15)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# Minimum number of samples required to split a node
min_samples_split = [2, 3, 5, 7, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2,3, 5,8, 10]

# %%
param_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

# %%
rf_random = RandomizedSearchCV(estimator = reg_rf, param_distributions = param_grid,scoring='neg_mean_squared_error', n_iter = 50, cv = 5,
                               verbose=2, random_state=42, n_jobs = 3)

# %%
rf_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_iter=50, n_jobs=3,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 3, 5, 8, 10],
#                                         'min_samples_split': [2, 3, 5, 7, 10,
#                                                               15, 100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100, 1200,
#                                                          1300, 1400, 1500]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 700,
#  'min_samples_split': 3,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 15}

# %%
reg_rf = RandomForestRegressor(n_estimators= 700,
 min_samples_split=3,
 min_samples_leaf= 1,
 max_features='sqrt',
 max_depth= 15)

# %%
reg_rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=15, max_features='sqrt', min_samples_split=3,
#                       n_estimators=700)

# %%
ypred1= reg_rf.predict(x_test)

# %%
ypred1
# Out:
# array([10220.6414744 ,  9037.64168767,  8590.80587426, ...,
#         4454.03843502,  7950.53115609,  9979.05139499])

# %%
plt.style.use("ggplot")
plt.figure(figsize=(12,8))
sns.distplot(y_test-ypred1)
plt.show()
# Out:
# C:\Users\bozkisaoglu\AppData\Local\Temp\ipykernel_36512\1552327531.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-ypred1)

# %%
plt.figure(figsize=(12,8))
plt.style.use("ggplot")
plt.scatter(y_test, ypred1, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_predq")
plt.show()

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, ypred1))
print('MSE:', metrics.mean_squared_error(y_test, ypred1))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, ypred1)))
# Out:
# MAE: 1560.3067157654293
# MSE: 6052450.857104741
# RMSE: 2460.172932357549

# %%
metrics.r2_score(y_test, ypred1)
# Out:
# 0.635960239797933

# %% [markdown]
# ### FLAML

# %%
from flaml import AutoML

# %%
Y_train = np.array(y_train)

# %%
automl = AutoML()

# %%
automl.fit(x_train, Y_train, task="regression",metric='r2',time_budget=500)
# Out:
# [flaml.automl: 10-06 22:58:50] {2600} INFO - task = regression
# [flaml.automl: 10-06 22:58:50] {2602} INFO - Data split method: uniform
# [flaml.automl: 10-06 22:58:50] {2605} INFO - Evaluation method: cv
# [flaml.automl: 10-06 22:58:51] {2727} INFO - Minimizing error metric: 1-r2
# [flaml.automl: 10-06 22:58:51] {2869} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth']
# [flaml.automl: 10-06 22:58:51] {3174} INFO - iteration 0, current learner lgbm
# [flaml.automl: 10-06 22:58:51] {3307} INFO - Estimated sufficient time budget=696s. Estimated necessary time budget=5s.
# [flaml.automl: 10-06 22:58:51] {3354} INFO -  at 0.1s,	estimator lgbm's best error=0.9274,	best estimator lgbm's best error=0.9274
# [flaml.automl: 10-06 22:58:51] {3174} INFO - iteration 1, current learner lgbm
# [flaml.automl: 10-06 22:58:51] {3354} INFO -  at 0.2s,	estimator lgbm's best error=0.9274,	best estimator lgbm's best error=0.9274
# [flaml.automl: 10-06 22:58:51] {3174} INFO - iteration 2, current learner lgbm
# [flaml.automl: 10-06 22:58:51] {3354} INFO -  at 0.3s,	estimator lgbm's best error=0.8228,	best estimator lgbm's best error=0.8228
# [flaml.automl: 10-06 22:58:51] {3174} INFO - iteration 3, current learner xgboost
# [flaml.automl: 10-06 22:58:51] {3354} INFO -  at 0.4s,	estimator xgboost's best error=4.9724,	best estimator lgbm's best error=0.8228
# [flaml.automl: 10-06 22:58:51] {3174} INFO - iteration 4, current learner extra_tree
# [flaml.automl: 10-06 22:58:51] {3354} INFO -  at 0.5s,	estimator extra_tree's best error=0.6248,	best estimator extra_tree's best error=0.6248
	best estimator rf's best error=0.3196
# [flaml.automl: 10-06 23:07:01] {3174} INFO - iteration 655, current learner xgb_limitdepth
# [flaml.automl: 10-06 23:07:02] {3354} INFO -  at 491.8s,	estimator xgb_limitdepth's best error=0.3364,	best estimator rf's best error=0.3196
# [flaml.automl: 10-06 23:07:02] {3174} INFO - iteration 656, current learner rf
# [flaml.automl: 10-06 23:07:04] {3354} INFO -  at 493.9s,	estimator rf's best error=0.3196,	best estimator rf's best error=0.3196
# [flaml.automl: 10-06 23:07:04] {3174} INFO - iteration 657, current learner xgb_limitdepth
# [flaml.automl: 10-06 23:07:05] {3354} INFO -  at 494.6s,	estimator xgb_limitdepth's best error=0.3364,	best estimator rf's best error=0.3196
# [flaml.automl: 10-06 23:07:05] {3174} INFO - iteration 658, current learner rf
# [flaml.automl: 10-06 23:07:07] {3354} INFO -  at 496.7s,	estimator rf's best error=0.3196,	best estimator rf's best error=0.3196
# [flaml.automl: 10-06 23:07:07] {3174} INFO - iteration 659, current learner xgb_limitdepth
# [flaml.automl: 10-06 23:07:08] {3354} INFO -  at 497.9s,	estimator xgb_limitdepth's best error=0.3364,	best estimator rf's best error=0.3196
# [flaml.automl: 10-06 23:07:08] {3174} INFO - iteration 660, current learner xgboost
# [flaml.automl: 10-06 23:07:09] {3354} INFO -  at 498.1s,	estimator xgboost's best error=0.3716,	best estimator rf's best error=0.3196
# [flaml.automl: 10-06 23:07:09] {3174} INFO - iteration 661, current learner xgb_limitdepth
# [flaml.automl: 10-06 23:07:09] {3354} INFO -  at 498.2s,	estimator xgb_limitdepth's best error=0.3364,	best estimator rf's best error=0.3196
# [flaml.automl: 10-06 23:07:09] {3174} INFO - iteration 662, current learner rf
# [flaml.automl: 10-06 23:07:10] {3354} INFO -  at 499.3s,	estimator rf's best error=0.3196,	best estimator rf's best error=0.3196
# [flaml.automl: 10-06 23:07:10] {3174} INFO - iteration 663, current learner xgboost
# [flaml.automl: 10-06 23:07:10] {3354} INFO -  at 499.5s,	estimator xgboost's best error=0.3716,	best estimator rf's best error=0.3196
# [flaml.automl: 10-06 23:07:10] {3174} INFO - iteration 664, current learner xgboost
# [flaml.automl: 10-06 23:07:10] {3354} INFO -  at 499.8s,	estimator xgboost's best error=0.3716,	best estimator rf's best error=0.3196
# [flaml.automl: 10-06 23:07:10] {3174} INFO - iteration 665, current learner xgboost
# [flaml.automl: 10-06 23:07:10] {3354} INFO -  at 500.0s,	estimator xgboost's best error=0.3716,	best estimator rf's best error=0.3196
# [flaml.automl: 10-06 23:07:11] {3618} INFO - retrain rf for 0.4s
# [flaml.automl: 10-06 23:07:11] {3625} INFO - retrained model: RandomForestRegressor(max_features=0.5392369506919457, max_leaf_nodes=436,
#                       n_estimators=123, n_jobs=-1)
# [flaml.automl: 10-06 23:07:11] {2900} INFO - fit succeeded
# [flaml.automl: 10-06 23:07:11] {2901} INFO - Time taken to find the best model: 265.2990770339966

# %%
print('Best ML leaner:', automl.best_estimator)
print('Best hyperparmeter config:', automl.best_config)
print('Best accuracy on validation data: {0:.4g}'.format(1-automl.best_loss))
print('Training duration of best run: {0:.4g} s'.format(automl.best_config_train_time))
# Out:
# Best ML leaner: rf
# Best hyperparmeter config: {'n_estimators': 123, 'max_features': 0.5392369506919457, 'max_leaves': 436}
# Best accuracy on validation data: 0.6804
# Training duration of best run: 0.4118 s

# %%
y_pred = automl.predict(x_test)
y_pred[:5]
# Out:
# array([ 5622.71121314, 14591.75603227,  6973.54575306, 12354.74712952,
#         7406.28720301])

# %%
# Model Değerlendirmesi
print('R^2:',metrics.r2_score(y_test, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_pred))*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R^2: 0.6627986937480976
# Adjusted R^2: 0.661446508058867
# MAE: 1526.611940016442
# MSE: 6052667.412245379
# RMSE: 2460.216944142402
